# %%
import random , csv
from pprint import pprint
import pandas as pd

class BMI(): 
    def __init__(self,name:str,height:int,weight:int): 
        self.name = name
        self.height = height
        self.weight = weight

    def get_bmi(self)->float: #取得bmi
        return round(self.weight / (self.height/100) ** 2,ndigits=2)
    
    def get_status(self)->str:  #取得status
        bmi = self.get_bmi()
        if bmi >=35:
            status = "重度肥胖"
        elif bmi >= 30:
            status = "中度肥胖"
        elif bmi >= 27:
            status = "輕度肥胖"
        elif bmi >= 24:
            status = "過重"
        elif bmi >= 18.5:
            status = "正常範圍"
        else:
            status = "體重過輕"
        return status

def get_name(nums:int=2)->list[str]: #抓取name.txt裡面的名字
    with open('names.txt',mode='r',encoding='utf-8') as file:
            names_str = file.read()
    names = names_str.split()
    names = random.choices(names,k=nums)
    return  names
     
def generate_bmi(names:list[str])->list[BMI]: 
    students:list[BMI] = []
    for name in names:
        height = random.randint(140,190)
        weight = random.randint(50,110)
        student_STATUS = BMI(name, height, weight)
        students.append(student_STATUS) #list實體化 
    return students

if __name__ == '__main__':
    nums = int(input('請輸入人數:'))
    names:list[str] = get_name(nums=nums)
    students:list[BMI] = generate_bmi(names=names)
    file_dict:list[dict] = []
    for student in students:
        #將資料轉換成字典
        student_dict = {
        "姓名": student.name,
        "身高": student.height,
        "體重": student.weight,
        "BMI": student.get_bmi(),
        "狀態": student.get_status()
        }
        file_dict.append(student_dict)  #寫入list[dict]
    
pprint(file_dict)#測試
df = pd.DataFrame(file_dict, 
                       columns=['姓名', '身高', '體重', 'BMI', '狀態'], #依據欄位名稱重新排序
                       index= range(1,nums+1)) #設定索引從1~nums(包含nums)
df.index.name = '學號'
df
# Out:
# [{'BMI': 17.02, '姓名': '李湘婷', '狀態': '體重過輕', '身高': 183, '體重': 57},
#  {'BMI': 27.76, '姓名': '黃必琪', '狀態': '輕度肥胖', '身高': 184, '體重': 94},
#  {'BMI': 20.2, '姓名': '簡國瑋', '狀態': '正常範圍', '身高': 178, '體重': 64},
#  {'BMI': 34.18, '姓名': '陳信宏', '狀態': '中度肥胖', '身高': 140, '體重': 67},
#  {'BMI': 23.16, '姓名': '楊易政', '狀態': '正常範圍', '身高': 187, '體重': 81},
#  {'BMI': 45.71, '姓名': '梁柏宇', '狀態': '重度肥胖', '身高': 153, '體重': 107},
#  {'BMI': 35.11, '姓名': '林建勳', '狀態': '重度肥胖', '身高': 177, '體重': 110},
#  {'BMI': 25.78, '姓名': '劉昀天', '狀態': '過重', '身高': 150, '體重': 58},
#  {'BMI': 24.19, '姓名': '胡淑貞', '狀態': '過重', '身高': 183, '體重': 81},
#  {'BMI': 21.33, '姓名': '王柏聖', '狀態': '正常範圍', '身高': 185, '體重': 73},
#  {'BMI': 21.71, '姓名': '林柏洋', '狀態': '正常範圍', '身高': 169, '體重': 62},
#  {'BMI': 44.73, '姓名': '高智超', '狀態': '重度肥胖', '身高': 151, '體重': 102},
#  {'BMI': 35.2, '姓名': '楊建安', '狀態': '重度肥胖', '身高': 159, '體重': 89},
#  {'BMI': 28.06, '姓名': '洪阿惠', '狀態': '輕度肥胖', '身高': 172, '體重': 83},
#  {'BMI': 37.02, '姓名': '王怡珊', '狀態': '重度肥胖', '身高': 166, '體重': 102},
#  {'BMI': 39.54, '姓名': '吳志宣', '狀態': '重度肥胖', '身高': 144, '體重': 82},
#  {'BMI': 42.98, '姓名': '簡美君', '狀態': '重度肥胖', '身高': 151, '體重': 98},
#  {'BMI': 29.52, '姓名': '王雅慧', '狀態': '輕度肥胖', '身高': 154, '體重': 70},
#  {'BMI': 25.11, '姓名': '張俊傑', '狀態': '過重', '身高': 184, '體重': 85},
#  {'BMI': 22.48, '姓名': '童建霖', '狀態': '正常範圍', '身高': 155, '體重': 54},
#  {'BMI': 25.43, '姓名': '王梅劭', '狀態': '過重', '身高': 174, '體重': 77},
#  {'BMI': 37.81, '姓名': '王坤安', '狀態': '重度肥胖', '身高': 169, '體重': 108},
#  {'BMI': 41.62, '姓名': '張凡成', '狀態': '重度肥胖', '身高': 155, '體重': 100},
#  {'BMI': 38.05, '姓名': '李美洋', '狀態': '重度肥胖', '身高': 145, '體重': 80},
#  {'BMI': 39.61, '姓名': '胡芳瑜', '狀態': '重度肥胖', '身高': 143, '體重': 81},
#  {'BMI': 24.22, '姓名': '楊綺芬', '狀態': '過重', '身高': 160, '體重': 62},
#  {'BMI': 24.53, '姓名': '李湘婷', '狀態': '過重', '身高': 147, '體重': 53},
#  {'BMI': 37.44, '姓名': '林麗萍', '狀態': '重度肥胖', '身高': 148, '體重': 82},
#  {'BMI': 27.14, '姓名': '林向鈺', '狀態': '輕度肥胖', '身高': 164, '體重': 73},
#  {'BMI': 37.34, '姓名': '趙宛真', '狀態': '重度肥胖', '身高': 162, '體重': 98},
#  {'BMI': 31.05, '姓名': '羅幸娥', '狀態': '中度肥胖', '身高': 174, '體重': 94},
#  {'BMI': 35.06, '姓名': '林詠斌', '狀態': '重度肥胖', '身高': 162, '體重': 92},
#  {'BMI': 48.51, '姓名': '林佳慧', '狀態': '重度肥胖', '身高': 145, '體重': 102},
#  {'BMI': 51.12, '姓名': '陳志偉', '狀態': '重度肥胖', '身高': 144, '體重': 106},
#  {'BMI': 32.11, '姓名': '鄭奇翰', '狀態': '中度肥胖', '身高': 172, '體重': 95},
#  {'BMI': 24.86, '姓名': '郎慧萍', '狀態': '過重', '身高': 169, '體重': 71},
#  {'BMI': 23.51, '姓名': '蔡明平', '狀態': '正常範圍', '身高': 165, '體重': 64},
#  {'BMI': 28.54, '姓名': '魏秋萍', '狀態': '輕度肥胖', '身高': 145, '體重': 60},
#  {'BMI': 27.73, '姓名': '林怡偉', '狀態': '輕度肥胖', '身高': 173, '體重': 83},
#  {'BMI': 46.46, '姓名': '蔡嘉音', '狀態': '重度肥胖', '身高': 143, '體重': 95}]
#      姓名   身高   體重    BMI    狀態
# 學號
# 1   李湘婷  183   57  17.02  體重過輕
# 2   黃必琪  184   94  27.76  輕度肥胖
# 3   簡國瑋  178   64  20.20  正常範圍
# 4   陳信宏  140   67  34.18  中度肥胖
# 5   楊易政  187   81  23.16  正常範圍
# 6   梁柏宇  153  107  45.71  重度肥胖
# 7   林建勳  177  110  35.11  重度肥胖
# 8   劉昀天  150   58  25.78    過重
# 9   胡淑貞  183   81  24.19    過重
# 10  王柏聖  185   73  21.33  正常範圍
# 11  林柏洋  169   62  21.71  正常範圍
# 12  高智超  151  102  44.73  重度肥胖
# 13  楊建安  159   89  35.20  重度肥胖
# 14  洪阿惠  172   83  28.06  輕度肥胖
# 15  王怡珊  166  102  37.02  重度肥胖
# 16  吳志宣  144   82  39.54  重度肥胖
# 17  簡美君  151   98  42.98  重度肥胖
# 18  王雅慧  154   70  29.52  輕度肥胖
# 19  張俊傑  184   85  25.11    過重
# 20  童建霖  155   54  22.48  正常範圍
# 21  王梅劭  174   77  25.43    過重
# 22  王坤安  169  108  37.81  重度肥胖
# 23  張凡成  155  100  41.62  重度肥胖
# 24  李美洋  145   80  38.05  重度肥胖
# 25  胡芳瑜  143   81  39.61  重度肥胖
# 26  楊綺芬  160   62  24.22    過重
# 27  李湘婷  147   53  24.53    過重
# 28  林麗萍  148   82  37.44  重度肥胖
# 29  林向鈺  164   73  27.14  輕度肥胖
# 30  趙宛真  162   98  37.34  重度肥胖
# 31  羅幸娥  174   94  31.05  中度肥胖
# 32  林詠斌  162   92  35.06  重度肥胖
# 33  林佳慧  145  102  48.51  重度肥胖
# 34  陳志偉  144  106  51.12  重度肥胖
# 35  鄭奇翰  172   95  32.11  中度肥胖
# 36  郎慧萍  169   71  24.86    過重
# 37  蔡明平  165   64  23.51  正常範圍
# 38  魏秋萍  145   60  28.54  輕度肥胖
# 39  林怡偉  173   83  27.73  輕度肥胖
# 40  蔡嘉音  143   95  46.46  重度肥胖

# %%
sdata = {'台北':[35000,60000,74000], '桃園':[71000,90000,120000], '台中':[16000,71000,90000], '高雄':[5000,34008,65000]}
pprint(sdata)
# Out:
# {'台中': [16000, 71000, 90000],
#  '台北': [35000, 60000, 74000],
#  '桃園': [71000, 90000, 120000],
#  '高雄': [5000, 34008, 65000]}

# %%
df2 = pd.DataFrame(sdata)
df2
# Out:
#       台北      桃園     台中     高雄
# 0  35000   71000  16000   5000
# 1  60000   90000  71000  34008
# 2  74000  120000  90000  65000
